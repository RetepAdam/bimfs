# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/cbb_comp_list.csv')
df_nba = pd.read_csv('data/nba_inputs.csv')

# %%
df[df['Player'].isin(df_nba['Player'])]
# Out:
#                  Player  From    To                     School       Conf  \
# 317       Kyle Anderson  2012  2015                   Delaware        CAA
# 326       Ryan Anderson  2012  2016                      Total      Total
# 1085       Devin Booker  2011  2013                    Clemson        ACC
# 1352      Anthony Brown  2016  2016                  Green Bay    Horizon
# 1357        Bobby Brown  2013  2016              Alabama State       SWAC
# 4505       Devin Harris  2014  2017                      Total      Total
# 4522         Joe Harris  2012  2012           Central Arkansas  Southland
# 4828        Jordan Hill  2014  2017                  Wisconsin    Big Ten
# 5544      James Johnson  2012  2015                      Total      Total
# 5545      James Johnson  2011  2014                      Total      Total
# 5546      James Johnson  2011  2012                 Quinnipiac        NEC
# 5647     Wesley Johnson  2015  2016        Charleston Southern  Big South
# ...

# %%
df.to_csv('data/cbb_comp_list.csv', index=False)

# %%
df2 = pd.read_csv('data/cbb_comp_list.csv')

# %%
# change isaiah taylor texas to df2.iloc[10784]
# Out:
# Player         Kevin Thompson
# From                     2011
# To                       2012
# School           Morgan State
# Conf                     MEAC
# G                          60
# MP                       1738
# FG                        274
# FGA                       531
# 2P                        273
# 2PA                       530
# 3P                          1
# 3PA                         1
# FT                        169
# FTA                       287
# ORB                       199
# DRB                       323
# TRB                       522
# AST                        82
# STL                        38
# BLK                        74
# TOV                       158
# PF                        163
# PTS                       718
# PProd                     714
# OWS                       2.6
# DWS                       2.8
# WS                        5.4
# PER                      20.4
# Unnamed: 29               NaN
#                     ...
# ...
